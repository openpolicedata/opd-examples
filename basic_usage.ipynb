# %% [markdown]
# This notebook shows examples of the following tasks:
# * Query for the entire table of available data
# * Query for all available datasets from a state (ex. Maryland)
# * Query for all stops data containing both traffic and investigatory stops in a state (ex. Virginia)
# * Show how to access the data by creating a source using a police department name or a state (ex. Virginia)
# * Find out what types of data are available from a source
# * Show the data in the source

# %%
import openpolicedata as opd

# %%
# Query for the entire table of available data
datasets = opd.datasets_query()
datasets.head()
# Out:
#       State      SourceName          Agency          TableType   Year  \
# 0  Virginia        Virginia           MULTI              STOPS  MULTI
# 1  Virginia  Fairfax County  Fairfax County   TRAFFIC WARNINGS   2019
# 2  Virginia  Fairfax County  Fairfax County   TRAFFIC WARNINGS   2020
# 3  Virginia  Fairfax County  Fairfax County  TRAFFIC CITATIONS   2019
# 4  Virginia  Fairfax County  Fairfax County  TRAFFIC CITATIONS   2020
#
#                                          Description DataType  \
# 0  A data collection consisting of all traffic an...  Socrata
# 1   Traffic Warnings issued by Fairfax County Police   ArcGIS
# 2   Traffic Warnings issued by Fairfax County Police   ArcGIS
# 3  Traffic Citations issued by Fairfax County Police   ArcGIS
# 4  Traffic Citations issued by Fairfax County Police   ArcGIS
#
#                                                  URL     date_field  \
# 0                                  data.virginia.gov  incident_date
# 1  https://services9.arcgis.com/kYvfX7YK8OobHItA/...        actdate
# 2  https://services9.arcgis.com/kYvfX7YK8OobHItA/...        actdate
# 3  https://services9.arcgis.com/kYvfX7YK8OobHItA/...        tc_date
# 4  https://services9.arcgis.com/kYvfX7YK8OobHItA/...        tc_date
#
#   dataset_id agency_field min_version  \
# 0  2c96-texw  agency_name        <NA>
# 1       <NA>         <NA>        <NA>
# 2       <NA>         <NA>        <NA>
# 3       <NA>         <NA>        <NA>
# 4       <NA>         <NA>        <NA>
#
#                                               readme
# 0  https://data.virginia.gov/api/views/2c96-texw/...
# 1                                               <NA>
# 2                                               <NA>
# 3                                               <NA>
# 4                                               <NA>

# %%
# Query for all available datasets from Maryland
df = opd.datasets_query(state="Maryland")
df.head()
# Out:
#        State         SourceName             Agency      TableType   Year  \
# 5   Maryland  Montgomery County  Montgomery County  TRAFFIC STOPS  MULTI
# 6   Maryland  Montgomery County  Montgomery County     COMPLAINTS  MULTI
# 53  Maryland          Baltimore          Baltimore          STOPS  MULTI
# 54  Maryland           Maryland              MULTI  TRAFFIC STOPS  MULTI
#
#                                           Description DataType  \
# 5   This dataset contains traffic violation inform...  Socrata
# 6   This dataset contains allegations brought to t...  Socrata
# 53  Standardized stop data from the Stanford Open ...      CSV
# 54  Standardized stop data from the Stanford Open ...      CSV
#
#                                                   URL    date_field  \
# 5                         data.montgomerycountymd.gov  date_of_stop
# 6                         data.montgomerycountymd.gov    created_dt
# 53  https://stacks.stanford.edu/file/druid:yg821jf...          date
# 54  https://stacks.stanford.edu/file/druid:yg821jf...          date
#
#    dataset_id     agency_field min_version  \
# 5   4mse-ku6q             <NA>        <NA>
# 6   usip-62e2             <NA>        <NA>
# 53       <NA>             <NA>        <NA>
# 54       <NA>  department_name        <NA>
#
#                                                readme
# 5   https://data.montgomerycountymd.gov/Public-Saf...
# 6   https://data.montgomerycountymd.gov/Public-Saf...
# 53  https://github.com/stanford-policylab/opp/blob...
# 54  https://github.com/stanford-policylab/opp/blob...

# %%
# Query for all stops data containing both traffic and investigatory stops in Virginia
df = opd.datasets_query(table_type=opd.defs.TableType.STOPS, state="Virginia")
df.head()
# Out:
#       State SourceName Agency TableType   Year  \
# 0  Virginia   Virginia  MULTI     STOPS  MULTI
#
#                                          Description DataType  \
# 0  A data collection consisting of all traffic an...  Socrata
#
#                  URL     date_field dataset_id agency_field min_version  \
# 0  data.virginia.gov  incident_date  2c96-texw  agency_name        <NA>
#
#                                               readme
# 0  https://data.virginia.gov/api/views/2c96-texw/...

# %%
# To access the data, create a source using a Source Name (usually a police department name). There is an optional state input to clarify ambiguities.
# Create data source for Virginia

src = opd.Source(source_name="Virginia", state="Virginia")
src.datasets.head()
# Out:
#       State SourceName Agency TableType   Year  \
# 0  Virginia   Virginia  MULTI     STOPS  MULTI
#
#                                          Description DataType  \
# 0  A data collection consisting of all traffic an...  Socrata
#
#                  URL     date_field dataset_id agency_field min_version  \
# 0  data.virginia.gov  incident_date  2c96-texw  agency_name        <NA>
#
#                                               readme
# 0  https://data.virginia.gov/api/views/2c96-texw/...

# %%
# Find out what types of data are available from this source

types = src.get_tables_types()

print(types)
# Out:
# ['STOPS']

# %%
# Find out what years are available from the stops table

years = src.get_years(table_type=types[0])
print(years)
# Out:
# [2020, 2021, 2022]

# %%
# Find out what agencies are contained in the stops table
agencies = src.get_agencies()
N = 20
print(f"Printing out {N} of {len(agencies)} agencies")
print(agencies[0:20])
# Out:
# Printing out 20 of 334 agencies
# ["Page County Sheriff's Office", 'Henrico Police Department', 'Haysi Police Department', 'Chatham Police Department', "Brunswick CO Sheriff's Office", 'Onley Police Department', 'Emporia Police Department', "Dickenson County Sheriff's Office", 'Tazewell Police Department', "King George County Sheriff's Office", 'Capitol Police Department', 'Glade Spring Police Department', "Pulaski CO Sheriff's Office", "King William Sheriff's Office", 'Eastern Virginia Medical School Police Department', 'Pembroke Police Department', "Culpeper County Sheriff's Office", "Bland County Sheriff's Office", 'Rural Retreat Police Dept', 'Bedford Police Department']

# %%
# Find out what jurisdictions are contained in the stops table that contain the word "Arlington"
jurisdictions = src.get_agencies(partial_name="Arlington")
print(jurisdictions)
# Out:
# ['Arlington County Police Department', "Arlington County Sheriff's Office"]

# %%
# Load data from the source for the Arlington County Police Department in 2021
agency = "Arlington County Police Department"
t = src.load_from_url(year=2021, table_type=opd.defs.TableType.STOPS, agency=agency)

# %%
# Show the first 5 rows of the table
t.table.head(n=5)
# Out:
#   incident_date                         agency_name  jurisdiction  \
# 0    2021-01-01  Arlington County Police Department  ARLINGTON CO
# 1    2021-01-01  Arlington County Police Department  ARLINGTON CO
# 2    2021-01-01  Arlington County Police Department  ARLINGTON CO
# 3    2021-01-01  Arlington County Police Department  ARLINGTON CO
# 4    2021-01-01  Arlington County Police Department  ARLINGTON CO
#
#        reason_for_stop                       race     ethnicity age  gender  \
# 0    TRAFFIC VIOLATION  BLACK OR AFRICAN AMERICAN  NON-HISPANIC  21  FEMALE
# 1  EQUIPMENT VIOLATION                      WHITE  NON-HISPANIC  23    MALE
# 2  EQUIPMENT VIOLATION                      WHITE  NON-HISPANIC  53    MALE
# 3  EQUIPMENT VIOLATION                      WHITE  NON-HISPANIC  53    MALE
# 4    TRAFFIC VIOLATION  BLACK OR AFRICAN AMERICAN  NON-HISPANIC  27    MALE
#
#        action_taken violation_type specific_violation person_searched  \
# 0           WARNING   COMMONWEALTH           46.2-613              NO
# 1           WARNING   COMMONWEALTH          46.2-1030              NO
# 2           WARNING   COMMONWEALTH           46.2-612              NO
# 3  CITATION/SUMMONS   COMMONWEALTH           46.2-301              NO
# 4           WARNING   COMMONWEALTH          46.2-1030              NO
#
#   vehicle_searched additional_arrest person_type english_speaking  \
# 0              YES                NO         NaN              NaN
# 1               NO                NO         NaN              NaN
# 2               NO                NO         NaN              NaN
# 3               NO                NO         NaN              NaN
# 4               NO                NO         NaN              NaN
#
#   virginia_crime_code physical_force_by_officer physical_force_by_subject
# 0                 NaN                       NaN                       NaN
# 1                 NaN                       NaN                       NaN
# 2                 NaN                       NaN                       NaN
# 3                 NaN                       NaN                       NaN
# 4                 NaN                       NaN                       NaN
